# %% [markdown]
# <a href="https://colab.research.google.com/github/sampada1516/Mercedes/blob/main/Mercedes_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mercedes-Benz Greener Manufacturing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.decomposition import PCA
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# importing dataset

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (4209, 378)

# %%
test.shape
# Out:
# (4209, 377)

# %%
train
# Out:
#         ID       y  X0 X1  X2 X3 X4  ... X378 X379 X380  X382  X383  X384  X385
# 0        0  130.81   k  v  at  a  d  ...    0    0    0     0     0     0     0
# 1        6   88.53   k  t  av  e  d  ...    0    0    0     0     0     0     0
# 2        7   76.26  az  w   n  c  d  ...    0    0    0     1     0     0     0
# 3        9   80.62  az  t   n  f  d  ...    0    0    0     0     0     0     0
# 4       13   78.02  az  v   n  f  d  ...    0    0    0     0     0     0     0
# ...    ...     ...  .. ..  .. .. ..  ...  ...  ...  ...   ...   ...   ...   ...
# 4204  8405  107.39  ak  s  as  c  d  ...    0    0    0     0     0     0     0
# 4205  8406  108.77   j  o   t  d  d  ...    0    0    0     0     0     0     0
# 4206  8412  109.22  ak  v   r  a  d  ...    0    0    0     0     0     0     0
# 4207  8415   87.48  al  r   e  f  d  ...    0    0    0     0     0     0     0
# 4208  8417  110.85   z  r  ae  c  d  ...    0    0    0     0     0     0     0
#
# [4209 rows x 378 columns]

# %%
test
# Out:
#         ID  X0  X1  X2 X3 X4  X5  ... X378 X379  X380  X382  X383  X384  X385
# 0        1  az   v   n  f  d   t  ...    1    0     0     0     0     0     0
# 1        2   t   b  ai  a  d   b  ...    0    0     0     0     0     0     0
# 2        3  az   v  as  f  d   a  ...    1    0     0     0     0     0     0
# 3        4  az   l   n  f  d   z  ...    1    0     0     0     0     0     0
# 4        5   w   s  as  c  d   y  ...    0    0     0     0     0     0     0
# ...    ...  ..  ..  .. .. ..  ..  ...  ...  ...   ...   ...   ...   ...   ...
# 4204  8410  aj   h  as  f  d  aa  ...    0    0     0     0     0     0     0
# 4205  8411   t  aa  ai  d  d  aa  ...    0    0     0     0     0     0     0
# 4206  8413   y   v  as  f  d  aa  ...    0    0     0     0     0     0     0
# 4207  8414  ak   v  as  a  d  aa  ...    0    0     0     0     0     0     0
# 4208  8416   t  aa  ai  c  d  aa  ...    0    0     0     0     0     0     0
#
# [4209 rows x 377 columns]

# %% [markdown]
# 1) If for any column(s), the variance is equal to zero, then you need to remove those variable(s).

# %%
var_df=pd.DataFrame(np.var(train,0),columns=['variance'])
var_df.sort_values(by='variance')
# Out:
#           variance
# X289  0.000000e+00
# X330  0.000000e+00
# X268  0.000000e+00
# X347  0.000000e+00
# X107  0.000000e+00
# ...            ...
# X362  2.495874e-01
# X337  2.497273e-01
# X127  2.499763e-01
# y     1.607285e+02
# ID    5.940524e+06
#
# [370 rows x 1 columns]

# %%
col=list((var_df[var_df['variance']==0]).index)
print('columns with variance 0',col)
# Out:
# columns with variance 0 ['X11', 'X93', 'X107', 'X233', 'X235', 'X268', 'X289', 'X290', 'X293', 'X297', 'X330', 'X347']

# %%
train.drop(col,axis=1,inplace=True)

# %%
train.shape
# Out:
# (4209, 366)

# %% [markdown]
# 2) Check for null and unique values for test and train sets.

# %%
value1=train.isna().sum().value_counts()
print('missing value in train dataset =', value1)
# Out:
# missing value in train dataset = 0    366
# dtype: int64

# %%
print('Number of unique values in train dataset =',train.nunique())
# Out:
# Number of unique values in train dataset = ID      4209
# y       2545
# X0        47
# X1        27
# X2        44
#         ...
# X380       2
# X382       2
# X383       2
# X384       2
# X385       2
# Length: 366, dtype: int64

# %%
value2=test.isna().sum().value_counts()
print('missing value in test dataset =', value2)
# Out:
# missing value in test dataset = 0    377
# dtype: int64

# %%
print('Number of unique values in test dataset=',test.nunique())
# Out:
# Number of unique values in test dataset= ID      4209
# X0        49
# X1        27
# X2        45
# X3         7
#         ...
# X380       2
# X382       2
# X383       2
# X384       2
# X385       2
# Length: 377, dtype: int64

# %% [markdown]
# 3) Apply label encoder.

# %%
object_col=[]
for i in train.columns:
    a= train[i].dtype
    if a =='object':
        object_col.append(i)
print(object_col)
# Out:
# ['X0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X8']

# %%
for i in object_col:
    print(i, train[i].nunique())
# Out:
# X0 47
# X1 27
# X2 44
# X3 7
# X4 4
# X5 29
# X6 12
# X8 25

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for i in object_col:
    train[i]=LE.fit_transform(train[i])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Columns: 366 entries, ID to X385
# dtypes: float64(1), int64(365)
# memory usage: 11.8 MB

# %% [markdown]
# 4) Perform dimensionality reduction.

# %%
# ?PCA

# %%
train
# Out:
#         ID       y  X0  X1  X2  X3  ...  X379  X380  X382  X383  X384  X385
# 0        0  130.81  32  23  17   0  ...     0     0     0     0     0     0
# 1        6   88.53  32  21  19   4  ...     0     0     0     0     0     0
# 2        7   76.26  20  24  34   2  ...     0     0     1     0     0     0
# 3        9   80.62  20  21  34   5  ...     0     0     0     0     0     0
# 4       13   78.02  20  23  34   5  ...     0     0     0     0     0     0
# ...    ...     ...  ..  ..  ..  ..  ...   ...   ...   ...   ...   ...   ...
# 4204  8405  107.39   8  20  16   2  ...     0     0     0     0     0     0
# 4205  8406  108.77  31  16  40   3  ...     0     0     0     0     0     0
# 4206  8412  109.22   8  23  38   0  ...     0     0     0     0     0     0
# 4207  8415   87.48   9  19  25   5  ...     0     0     0     0     0     0
# 4208  8417  110.85  46  19   3   2  ...     0     0     0     0     0     0
#
# [4209 rows x 366 columns]

# %%
xdata=train.drop('y',axis=1)
xdata.shape
# Out:
# (4209, 365)

# %%
ydata=train['y']
ydata.shape
# Out:
# (4209,)

# %%
PCA1=PCA(random_state=0)
Principal_comp=PCA1.fit(xdata)

# %%
plt.plot(np.cumsum(PCA1.explained_variance_))
plt.title("Mercedes Dataset Explained variance")
plt.xlabel("Number of Components")
plt.ylabel("Variance")
plt.xlim(0,15)
plt.show()

# %%
PCA1=PCA(n_components=5)
Principal_data=PCA1.fit_transform(xdata)
PCA1
# Out:
# PCA(copy=True, iterated_power='auto', n_components=5, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
PCA1.explained_variance_ratio_
# Out:
# array([9.99915408e-01, 3.43250074e-05, 1.91351988e-05, 1.09402163e-05,
#        8.24910539e-06])

# %%
PCA1.explained_variance_ratio_.sum()
# Out:
# 0.9999880577468867

# %% [markdown]
# 5) Predict your test_df values using XGBoost.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(xdata,ydata,test_size=0.25,random_state=50)

# %%
XGboost=XGBRegressor()
xgbparams={'max_depth': [3,5,10,15], 'learning_rate' : [0.1], 'n_estimators' : [50,100,200,300],'random_state' :[0]}
grid=zip([XGboost],[xgbparams])
best_model=None
for model,param in grid:
    temp=GridSearchCV(model,param_grid=param,cv=3,n_jobs=1)
    temp.fit(X_train,Y_train)
    if best_model is None:
        best_model=temp
    else:
        if temp.best_score_ > best_model.best_score_:
            best_model = temp
print ("Best CV Score",best_model.best_score_)
print ("Model Parameters",best_model.best_params_)
print("Best Estimator",best_model.best_estimator_)
# Out:
# [05:24:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:24:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:25:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:26:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:26:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:28:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:28:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:28:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:29:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:29:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Best CV Score 0.5565276004354923
# Model Parameters {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'random_state': 0}
# Best Estimator XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=50,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
model=best_model.best_estimator_
model.fit(X_train,Y_train)
pred=model.predict(X_test)
# Out:
# [05:29:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
r2_score(Y_test,pred)
# Out:
# 0.5878823597565768

# %%
print(model.score(X_train,Y_train))
print(model.score(X_test,Y_test))
# Out:
# 0.5899542032558875
# 0.5878823597565768

# %% [markdown]
# Conclusion :
# 1)there are total 12 columns with variance 0 that are removed.
# 2)there is no missing value in our train and test dataset.
# 3)Applied label encoder.
# 4)Performed dimensionality reduction using PCA get 94% variance for 5 component.
# 5) After applying Xgboost regressor algorithm, get accuracy of 60% and it can be used for test prediction
